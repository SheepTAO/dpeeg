# %%
import os
import sys

BOOTPATH = os.path.dirname(sys.path[0])
sys.path.append(BOOTPATH)

from dpeeg.data.datasets import HGD

# %%
raw = HGD()
# Out:
# Reading High Gamma Dataset ...
# Tensorflow not install, you could not use those pipelines
# To use the get_shape_from_baseconcar, InputShapeSetterEEG, BraindecodeDatasetLoaderyou need to install `braindecode`.`pip install braindecode` or Please refer to `https://braindecode.org`.

# %%
raw.items()
# Out:
# dict_items([(1, {'train': [array([[[-1.79980479e-05, -1.92196937e-05, -2.82334594e-05, ...,
#          -1.25171501e-05, -2.06064269e-05, -3.27568509e-05],
#         [-2.46345566e-05, -2.64505167e-05, -3.33511652e-05, ...,
#          -2.26865267e-05, -2.49317137e-05, -3.02145068e-05],
#         [-1.74367511e-05, -1.90876239e-05, -2.14978983e-05, ...,
#          -2.26204918e-05, -2.60212898e-05, -2.97192449e-05],
#         ...,
#         [ 1.90441156e-04,  1.80965146e-04,  1.70828786e-04, ...,
#           1.78059609e-04,  1.79908587e-04,  1.83243350e-04],
#         [ 1.93676866e-04,  1.92422203e-04,  1.82219809e-04, ...,
#           1.82814123e-04,  1.87172427e-04,  1.90705295e-04],
#         [ 1.96582403e-04,  1.89813824e-04,  1.79710482e-04, ...,
#           1.86082851e-04,  1.89318562e-04,  1.92587290e-04]],
#
#        [[-1.11304169e-05, -1.10973994e-05, -1.32435341e-05, ...,
#          -2.66486215e-05, -2.27525616e-05, -2.89928609e-05],
# ...
